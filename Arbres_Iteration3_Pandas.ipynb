# %%
### Madifications apres nbdime

# %% [markdown]
# # Ouvrir le fichier CSV contenant les données (comma separated values):
#     How to read data from a CSV file or a text file?
#
#     Explanation:
# ‘read_csv’ function has a plethora of parameters and I have specified only a few, ones that you may use most often. A few key points:
#
# a) header=0 means you have the names of columns in the first row in the file and if you don’t you will have to specify header=None
#
# b) index_col = False means to not use the first column of the data as an index in the data frame, you might want to set it to true if the first column is really an index.
#
# c) names = None implies you are not specifying the column names and want it to be inferred from csv file, which means that your header = some_number contains column names. Otherwise, you can specify the names in here in the same order as you have the data in the csv file.
# If you are reading a text file separated by space or tab, you could simply change the sep to be:
# sep = " " or sep='\t'

# %%
#Extraire l’ensemble des lignes (rows) et stocker ces informations dans une variable de type List 

import pandas as pd
import csv
df = pd.read_csv('trees.csv', sep=',', header=0, index_col=False, names=None)
df
# Out:
#        ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0              37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1              37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
# 2              37991  ESP37967  ESP37967   VEG  VEGETATION     ESP01
# 3              37990  ESP37966  ESP37966   VEG  VEGETATION     ESP01
# 4              37989  ESP37965  ESP37965   VEG  VEGETATION     ESP01
# ...              ...       ...       ...   ...         ...       ...
# 31238           7598   ESP2513   ESP2513   VEG  VEGETATION     ESP01
# 31239           7596   ESP2512   ESP2512   VEG  VEGETATION     ESP01
# 31240           7594   ESP2511   ESP2511   VEG  VEGETATION     ESP01
# 31241             19   ESP1798   ESP1798   VEG  VEGETATION     ESP01
# 31242             17   ESP1797   ESP1797   VEG  VEGETATION     ESP01
#
#       CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  \
# ...

# %%
# afficher les premier 2 lignes
df[:2]
# Out:
#    ELEM_POINT_ID      CODE       NOM GENRE  GENRE_DESC CATEGORIE  \
# 0          37993  ESP37969  ESP37969   VEG  VEGETATION     ESP01
# 1          37992  ESP37968  ESP37968   VEG  VEGETATION     ESP01
#
#   CATEGORIE_DESC SOUS_CATEGORIE        SOUS_CATEGORIE_DESC CODE_PARENT  ...  \
# 0          Arbre         ESP065  Arbre d'enceintes fermées    ESP37898  ...
# 1          Arbre         ESP065  Arbre d'enceintes fermées    ESP37898  ...
#
#   COURRIER  IDENTIFIANTPLU TYPEIMPLANTATIONPLU INTITULEPROTECTIONPLU  \
# 0      NaN             NaN                 NaN                   NaN
# 1      NaN             NaN                 NaN                   NaN
#
#   ANNEEABATTAGE ESSOUCHEMENT DIAMETREARBRE  CAUSEABATTAGE  COLLECTIVITE  \
# 0           NaN          NaN           NaN            NaN           NaN
# 1           NaN          NaN           NaN            NaN           NaN
#
#                                              GeoJSON
# 0  {"type":"Point","coordinates":[5.7603469008942...
# ...

# %%
# Afficher la 2ème colonne de chacune de ces deux lignes.
df.iloc[:2, 1]
# Out:
# 0    ESP37969
# 1    ESP37968
# Name: CODE, dtype: object

# %%
df.iloc[:2, [1]]
# Out:
#        CODE
# 0  ESP37969
# 1  ESP37968

# %% [markdown]
# # Extraire l’information concernant l’année de plantation pour l’ensemble des lignes (rows) et stocker ces informations dans une autre variable de type List
# Vous pouvez essayer avec une boucle for : https://www.w3schools.com/python/python_for_loops.asp

# %%
annee_plantation = df['ANNEEDEPLANTATION']
annee_plantation.tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2000.0,
#  2017.0,
#  2009.0,
#  2009.0,
#  2009.0,
#  1983.0,
#  1983.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  1976.0,
#  2017.0,
#  2017.0,
#  2017.0,
#  2017.0,
# ...

# %% [markdown]
# # Afficher les 50 premières lignes et les 50 dernières lignes de cette liste.
# List slicing : https://www.geeksforgeeks.org/python-list-slicing/

# %%
premiers_50 = annee_plantation[:50]
print(premiers_50)
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13    2017.0
# 14    2017.0
# 15    2017.0
# 16    2017.0
# 17    2017.0
# 18    2017.0
# 19    2017.0
# 20    2017.0
# 21    2017.0
# 22    2017.0
# 23    2017.0
# 24    2017.0
# 25    2017.0
# 26    2017.0
# 27    2017.0
# 28    2017.0
# 29    2017.0
# 30    2017.0
# 31    2017.0
# 32    2017.0
# 33    2017.0
# 34    2017.0
# 35    2017.0
# 36    2017.0
# 37    2017.0
# 38    2017.0
# 39    2017.0
# 40    2017.0
# 41    2017.0
# 42    2017.0
# 43    2017.0
# 44    2017.0
# 45    2017.0
# 46    2017.0
# 47    2017.0
# 48    2017.0
# 49    2017.0
# Name: ANNEEDEPLANTATION, dtype: float64

# %%
derniers_50 = annee_plantation[-50:]
print(derniers_50)
# Out:
# 31193    1975.0
# 31194    1975.0
# 31195    1975.0
# 31196    1975.0
# 31197    1975.0
# 31198    1975.0
# 31199    1975.0
# 31200    1975.0
# 31201    1975.0
# 31202    1975.0
# 31203    1975.0
# 31204    1975.0
# 31205    1975.0
# 31206    1975.0
# 31207    1975.0
# 31208    1975.0
# 31209    1975.0
# 31210    1975.0
# 31211    1975.0
# 31212    1975.0
# 31213    1975.0
# 31214    2017.0
# 31215    2017.0
# 31216    2001.0
# 31217    2001.0
# 31218    2001.0
# 31219    2001.0
# 31220    2001.0
# 31221    2001.0
# 31222    2001.0
# 31223    2001.0
# 31224    2001.0
# 31225    2001.0
# 31226    2001.0
# 31227    2001.0
# 31228    2001.0
# 31229    2001.0
# 31230    2001.0
# 31231    2001.0
# 31232    2001.0
# 31233    2001.0
# 31234    2001.0
# 31235    2001.0
# 31236    2001.0
# 31237    2001.0
# 31238    2001.0
# 31239    2001.0
# 31240    2001.0
# 31241    2001.0
# 31242    2001.0
# Name: ANNEEDEPLANTATION, dtype: float64

# %% [markdown]
# # Combien d’arbres sont recensés dans ce jeu de données ?
# Function len : https://www.w3schools.com/python/ref_func_len.asp

# %%
arbres_recenses = len(annee_plantation)
print(arbres_recenses)
# Out:
# 31243

# %% [markdown]
# # Pour combien d’arbres manque-t-il l’information concernant la date de plantation ? (Vous pouvez essayer de le faire d’au moins deux manières différentes.)
# Function count : https://www.programiz.com/python-programming/methods/list/count

# %%
# premier version
annee_plantation.isnull().sum()
# Out:
# np.int64(442)

# %% [markdown]
# # Combien d’arbres ont été plantés l’année de votre naissance ?

# %%
birth_year_trees = (annee_plantation == 1984).sum()
print(birth_year_trees)
# Out:
# 666

# %%
year_1984 = df[df['ANNEEDEPLANTATION'] == 1984]
len(year_1984)
# Out:
# 666

# %%
annee_1984 = df['ANNEEDEPLANTATION'].value_counts('1984')
annee_1984
# Out:
# ANNEEDEPLANTATION
# 1975.0    0.127334
# 2001.0    0.052790
# 1980.0    0.049609
# 1970.0    0.046882
# 2015.0    0.032337
# 1985.0    0.032142
# 1976.0    0.031557
# 1978.0    0.029609
# 2014.0    0.028603
# 1995.0    0.025356
# 1987.0    0.025032
# 1965.0    0.024675
# 1960.0    0.024188
# 2009.0    0.022597
# 1984.0    0.021623
# 1981.0    0.020908
# 2006.0    0.019999
# 1977.0    0.019999
# 1999.0    0.019577
# 2011.0    0.017207
# 2010.0    0.015162
# 2000.0    0.014967
# 2005.0    0.014610
# 1982.0    0.014545
# 1990.0    0.014058
# 1950.0    0.013701
# 1996.0    0.012500
# 1972.0    0.011818
# 1979.0    0.011720
# 2004.0    0.011428
# 2003.0    0.011428
# 1974.0    0.011363
# 1969.0    0.011363
# 2016.0    0.011266
# 2002.0    0.011071
# 2012.0    0.010974
# 2013.0    0.010876
# 1983.0    0.010811
# 1989.0    0.009967
# 1994.0    0.009350
# 2017.0    0.008831
# 1988.0    0.008636
# 1997.0    0.007727
# 1986.0    0.007727
# 1992.0    0.007337
# 1998.0    0.007143
# ...

# %% [markdown]
# # Quelle est la plus ancienne année de plantation recensée dans ce dataset ? La plus récente ?

# %%
oldest_tree = annee_plantation.min()
print(oldest_tree)
# Out:
# 1950.0

# %%
youngest_tree = annee_plantation.max()
print(f"the youngest tree was seeded in {youngest_tree}")
# Out:
# the youngest tree was seeded in 2017.0

# %% [markdown]
# # Combien d’arbres ont été plantés année par année (ex : 1987 : 771, 1988 : 266, etc…) ?
# Fonction range : https://www.w3schools.com/python/ref_func_range.asp

# %%
tree_number_per_year = df['ANNEEDEPLANTATION'].value_counts()
tree_number_per_year.tolist()
tree_number_per_year
# Out:
# ANNEEDEPLANTATION
# 1975.0    3922
# 2001.0    1626
# 1980.0    1528
# 1970.0    1444
# 2015.0     996
# 1985.0     990
# 1976.0     972
# 1978.0     912
# 2014.0     881
# 1995.0     781
# 1987.0     771
# 1965.0     760
# 1960.0     745
# 2009.0     696
# 1984.0     666
# 1981.0     644
# 2006.0     616
# 1977.0     616
# 1999.0     603
# 2011.0     530
# 2010.0     467
# 2000.0     461
# 2005.0     450
# 1982.0     448
# 1990.0     433
# 1950.0     422
# 1996.0     385
# 1972.0     364
# 1979.0     361
# 2004.0     352
# 2003.0     352
# 1974.0     350
# 1969.0     350
# 2016.0     347
# 2002.0     341
# 2012.0     338
# 2013.0     335
# 1983.0     333
# 1989.0     307
# 1994.0     288
# 2017.0     272
# 1988.0     266
# 1997.0     238
# 1986.0     238
# 1992.0     226
# 1998.0     220
# 2008.0     219
# 1993.0     161
# 2007.0     155
# 1991.0     146
# 1968.0     116
# 1966.0      95
# 1971.0      75
# 1955.0      66
# 1967.0      57
# 1973.0      34
# 1961.0      27
# ...

# %%
tree_par_year_dic = dict(tree_number_per_year)
tree_par_year_dic
# Out:
# {1975.0: np.int64(3922),
#  2001.0: np.int64(1626),
#  1980.0: np.int64(1528),
#  1970.0: np.int64(1444),
#  2015.0: np.int64(996),
#  1985.0: np.int64(990),
#  1976.0: np.int64(972),
#  1978.0: np.int64(912),
#  2014.0: np.int64(881),
#  1995.0: np.int64(781),
#  1987.0: np.int64(771),
#  1965.0: np.int64(760),
#  1960.0: np.int64(745),
#  2009.0: np.int64(696),
#  1984.0: np.int64(666),
#  1981.0: np.int64(644),
#  2006.0: np.int64(616),
#  1977.0: np.int64(616),
#  1999.0: np.int64(603),
#  2011.0: np.int64(530),
#  2010.0: np.int64(467),
#  2000.0: np.int64(461),
#  2005.0: np.int64(450),
#  1982.0: np.int64(448),
#  1990.0: np.int64(433),
#  1950.0: np.int64(422),
#  1996.0: np.int64(385),
#  1972.0: np.int64(364),
#  1979.0: np.int64(361),
#  2004.0: np.int64(352),
#  2003.0: np.int64(352),
#  1974.0: np.int64(350),
#  1969.0: np.int64(350),
#  2016.0: np.int64(347),
#  2002.0: np.int64(341),
#  2012.0: np.int64(338),
#  2013.0: np.int64(335),
#  1983.0: np.int64(333),
# ...

# %% [markdown]
# # Combien d’arbres ont été plantés en moyenne chaque année ?
# Moyenne d’une liste de deux manières : https://www.geeksforgeeks.org/find-average-list-python/

# %%
tree_number_per_year.sum()
# Out:
# np.int64(30801)

# %%
# faire les calcules (par exemple la sum) sum quand a partir d'une liste
avg_tree_plantation = tree_number_per_year.sum() / len(tree_number_per_year)
print(avg_tree_plantation)
# Out:
# 531.051724137931

# %%
# faire les calcules (par exemple la sum) sum quand a partir d'un dictionaire
av_plantation = sum(tree_par_year_dic.values()) / len(tree_par_year_dic)
av_plantation
# Out:
# np.float64(531.051724137931)

# %% [markdown]
# # Stocker conjointement l’année de plantation et le nombre d’arbres plantés dans un tuple. Les tuples seront stockés dans une liste (ex : [ (‘1987’, 771), (‘1988’, 266), ….. ] )
# Les tuples en python : https://courspython.com/tuple.html

# %%
set_tree_par_year_TUPLE = set(tree_number_per_year)
set_tree_par_year_TUPLE
# Out:
# {7,
#  27,
#  34,
#  57,
#  66,
#  75,
#  95,
#  116,
#  146,
#  155,
#  161,
#  219,
#  220,
#  226,
#  238,
#  266,
#  272,
#  288,
#  307,
#  333,
#  335,
#  338,
#  341,
#  347,
#  350,
#  352,
#  361,
#  364,
#  385,
#  422,
#  433,
#  448,
#  450,
#  461,
#  467,
#  530,
#  603,
#  616,
#  644,
#  666,
#  696,
#  745,
#  760,
#  771,
#  781,
#  881,
#  912,
#  972,
#  990,
#  996,
#  1444,
#  1528,
#  1626,
#  3922}

# %%
tree_par_year_TUPLE_1 = tuple(set_tree_par_year_TUPLE)
tree_par_year_TUPLE_1
# Out:
# (385,
#  771,
#  644,
#  7,
#  1528,
#  266,
#  781,
#  912,
#  272,
#  530,
#  146,
#  666,
#  155,
#  27,
#  288,
#  161,
#  34,
#  1444,
#  422,
#  433,
#  307,
#  696,
#  57,
#  448,
#  450,
#  66,
#  75,
#  972,
#  461,
#  333,
#  335,
#  3922,
#  467,
#  338,
#  341,
#  1626,
#  603,
#  347,
#  220,
#  990,
#  350,
#  352,
#  219,
#  226,
#  95,
#  996,
#  616,
#  745,
#  361,
#  364,
#  238,
#  881,
#  116,
#  760)

# %% [markdown]
# # Quel Maire a planté le plus d’arbres à Grenoble ?

# %%
# chaque element de la liste est un dictionaire

maires = [
   {"nom": "Piolle", "debut": 2014, "fin": 2026},
   {"nom": "Destot", "debut": 1995, "fin": 2013},
   {"nom": "Carignon", "debut": 1983, "fin": 1994},
   {"nom": "Dubedout", "debut": 1965, "fin": 1982},
   {"nom": "Michallon", "debut": 1959, "fin": 1964},
   {"nom": "Marton", "debut": 1949, "fin": 1958}
]

# %%
df_maires = pd.DataFrame(maires)
df_maires
# Out:
#          nom  debut   fin
# 0     Piolle   2014  2026
# 1     Destot   1995  2013
# 2   Carignon   1983  1994
# 3   Dubedout   1965  1982
# 4  Michallon   1959  1964
# 5     Marton   1949  1958

# %%
df_arbres = pd.DataFrame(list(tree_par_year_dic.items()), columns=['Annee', 'nb_arbres'])
print(df_arbres)
# Out:
#      Annee  nb_arbres
# 0   1975.0       3922
# 1   2001.0       1626
# 2   1980.0       1528
# 3   1970.0       1444
# 4   2015.0        996
# 5   1985.0        990
# 6   1976.0        972
# 7   1978.0        912
# 8   2014.0        881
# 9   1995.0        781
# 10  1987.0        771
# 11  1965.0        760
# 12  1960.0        745
# 13  2009.0        696
# 14  1984.0        666
# 15  1981.0        644
# 16  2006.0        616
# 17  1977.0        616
# 18  1999.0        603
# 19  2011.0        530
# 20  2010.0        467
# 21  2000.0        461
# 22  2005.0        450
# 23  1982.0        448
# 24  1990.0        433
# 25  1950.0        422
# 26  1996.0        385
# 27  1972.0        364
# 28  1979.0        361
# 29  2004.0        352
# 30  2003.0        352
# 31  1974.0        350
# 32  1969.0        350
# 33  2016.0        347
# 34  2002.0        341
# 35  2012.0        338
# 36  2013.0        335
# 37  1983.0        333
# 38  1989.0        307
# 39  1994.0        288
# ...

# %%
# Fonction pour trouver le maire en fonction de l'année
def maire_de_l_annee(annee):
    # on filtre le DataFrame des maires
    m = df_maires[(df_maires['debut'] <= annee) & (df_maires['fin'] >= annee)]
    return m['nom'].values[0]  # récupère le nom du maire

# Appliquer la fonction sur df_arbres
df_arbres['maire'] = df_arbres['Annee'].apply(maire_de_l_annee)

print(df_arbres)
# Out:
#      Annee  nb_arbres      maire
# 0   1975.0       3922   Dubedout
# 1   2001.0       1626     Destot
# 2   1980.0       1528   Dubedout
# 3   1970.0       1444   Dubedout
# 4   2015.0        996     Piolle
# 5   1985.0        990   Carignon
# 6   1976.0        972   Dubedout
# 7   1978.0        912   Dubedout
# 8   2014.0        881     Piolle
# 9   1995.0        781     Destot
# 10  1987.0        771   Carignon
# 11  1965.0        760   Dubedout
# 12  1960.0        745  Michallon
# 13  2009.0        696     Destot
# 14  1984.0        666   Carignon
# 15  1981.0        644   Dubedout
# 16  2006.0        616     Destot
# 17  1977.0        616   Dubedout
# 18  1999.0        603     Destot
# 19  2011.0        530     Destot
# 20  2010.0        467     Destot
# 21  2000.0        461     Destot
# 22  2005.0        450     Destot
# 23  1982.0        448   Dubedout
# 24  1990.0        433   Carignon
# 25  1950.0        422     Marton
# 26  1996.0        385     Destot
# ...

# %%
df_arbres = df_arbres.sort_values(by='Annee', ascending=False)
df_arbres
# Out:
#      Annee  nb_arbres      maire
# 40  2017.0        272     Piolle
# 33  2016.0        347     Piolle
# 4   2015.0        996     Piolle
# 8   2014.0        881     Piolle
# 36  2013.0        335     Destot
# 35  2012.0        338     Destot
# 19  2011.0        530     Destot
# 20  2010.0        467     Destot
# 13  2009.0        696     Destot
# 46  2008.0        219     Destot
# 48  2007.0        155     Destot
# 16  2006.0        616     Destot
# 22  2005.0        450     Destot
# 29  2004.0        352     Destot
# 30  2003.0        352     Destot
# 34  2002.0        341     Destot
# 1   2001.0       1626     Destot
# 21  2000.0        461     Destot
# 18  1999.0        603     Destot
# 45  1998.0        220     Destot
# 42  1997.0        238     Destot
# 26  1996.0        385     Destot
# 9   1995.0        781     Destot
# 39  1994.0        288   Carignon
# 47  1993.0        161   Carignon
# 44  1992.0        226   Carignon
# 49  1991.0        146   Carignon
# ...

# %%
# count le maires
maire_count = df_arbres.groupby(['maire'])['nb_arbres'].sum()
maire_count
# Out:
# maire
# Carignon      4825
# Destot        9165
# Dubedout     13048
# Marton         488
# Michallon      779
# Piolle        2496
# Name: nb_arbres, dtype: int64

# %%
print(les_maires_et_leur_plantations[:10])
# Out:
# [('Piolle', 2496), ('Destot', 9165), ('Carignon', 4825), ('Dubedout', 13048), ('Michallon', 779), ('Marton', 488)]

# %%
print(len(correct_years))
# Out:
# 30801

# %%
print(correct_years[:10])
# Out:
# [2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017]

# %%
print(correct_years[-10:])
# Out:
# [2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001, 2001]

# %%
correct_years_unique =sorted(set(correct_years))
print(correct_years_unique[:100])
# Out:
# [1950, 1955, 1960, 1961, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017]

# %%
les_maires_et_leur_plantations = []

for maire in maires:
    count = 0
    for annee in correct_years_unique:
        if maire["debut"] <=  annee <= maire ["fin"]:
            count += 1
        les_maires_et_leur_plantations.append((maire["nom"], count))
    print(maire["nom"], ":", count)
# Out:
# Piolle : 4
# Destot : 19
# Carignon : 12
# Dubedout : 18
# Michallon : 3
# Marton : 2

# %% [markdown]
# # Récupérez maintenant l’information concernant le genre botanique et la stocker conjointement avec l’année de plantation dans un tuple. Les tuples seront stockés dans une liste (ex : [ (‘1987’, ‘Acer), (‘1988’, ‘Acerifolia), ….. ] )

# %%
index_genre = header.index("GENRE_BOTA")
print(index_genre)
# Out:
# 13

# %%
genre_bota = []
for ligne in treereader[1:]:
    genre = ligne[13].strip()
    genre_bota.append(genre)
print(genre_bota[:30])
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus']

# %%
# eliminer les cellules vides de la colonne GENRE_BOTA

genre_bota_correct = []
for a in genre_bota:
    if a.strip()!= "":
        genre_bota_correct.append(str(a))
print(genre_bota_correct[:30])
# Out:
# ['Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus', 'Platanus']

# %%
# utiliser la methode zip pour fusionner les 2 listes dans une liste des TUPLES

arbres_bota_tuple = list(zip(correct_years, genre_bota_correct))

for annee, genre in arbres_bota_tuple[:10]:
    print(f"{annee} : {genre}")
# Out:
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus

# %%
print(arbres_bota_tuple[:10])
# Out:
# [(2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus'), (2017, 'Platanus')]

# %%
# utiliser la methode zip pour fusionner les 2 listes dans une TUPLE
arbres_bota_tuple_2 = tuple(zip(correct_years, genre_bota_correct))

for annee, genre in arbres_bota_tuple_2[:10]:
    print(f"{annee} : {genre}")
# Out:
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus
# 2017 : Platanus

# %%
arbres_bota_tuple_2[:10]
# Out:
# ((2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'),
#  (2017, 'Platanus'))

# %% [markdown]
# # Pour combien d'arbres manque-t-il l’information concernant le genre botanique ?

# %%
count_genre_manquant = 0

for genre in genre_bota:
    if genre == "":
        count_genre_manquant += 1
print(f"Le numero d'arbres manquant de l'information est {count_genre_manquant}")
# Out:
# Le numero d'arbres manquant de l'information est 515

# %% [markdown]
# # Utilisez Matplotlib pour tracer l’histogramme représentant le nombre d’arbres plantés par année.
# Exemple : https://how2matplotlib.com/how-to-plot-histogram-from-list-of-data-in-matplotlib.html
# Doc officielle : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import colors
from matplotlib.ticker import PercentFormatter

correct_years_unique = sorted(list(set(correct_years)))
count_tree_per_year = [correct_years.count(annee) for annee in correct_years_unique]

plt.figure(figsize=(10,6))
plt.bar(correct_years_unique, count_tree_per_year, color='green')

plt.xlabel("annee de plantation")
plt.ylabel("Nombre d'arbres plantés")
plt.title("Histograme des arbres plantés par annee")
plt.grid(axis='y', linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# # (plus dur) Triez les tuples (année, genre_botanique) en fonction de l’année de plantation par ordre décroissant.

# %%
arbores_uniques = set(arbres_bota_tuple_2)
arbores_uniques
# Out:
# {(2011, 'Syringa'),
#  (2001, 'Fagus'),
#  (2013, 'Crataegus'),
#  (2007, 'Magnolia'),
#  (1993, 'Carpinus'),
#  (2000, 'Chamaecyparis'),
#  (1975, 'Tilia'),
#  (1999, 'Koelreuteria'),
#  (1987, 'Rhus'),
#  (1960, 'Thuja'),
#  (1984, 'Araucaria'),
#  (1969, 'Gleditsia'),
#  (1984, 'Cedrus'),
#  (1969, 'Picea'),
#  (1971, 'Prunus'),
#  (1976, 'Tilia'),
#  (1950, 'Koelreuteria'),
#  (2010, 'Cornus'),
#  (2009, 'Amélanchier'),
#  (1974, 'Ilex'),
#  (1981, 'Morus'),
#  (2014, 'Catalpa'),
#  (1982, 'Fagus'),
#  (1997, 'Fraxinus'),
#  (1974, 'Carpinus'),
#  (1990, 'Thuja'),
#  (1999, 'Gleditsia'),
#  (1976, 'Cedrus'),
#  (1999, 'Picea'),
#  (2015, 'Metasequoia'),
#  (2003, 'Corylus'),
#  (2006, 'Tilia'),
#  (1980, 'Koelreuteria'),
#  (2012, 'Pinus'),
#  (1976, 'Salix'),
#  (1978, 'Cephalotaxus'),
#  (1950, 'Gleditsia'),
#  (2011, 'Morus'),
#  (2010, 'Ulmus'),
#  (2015, 'Malus'),
#  (2002, 'Prunus'),
#  (2004, 'Carpinus'),
#  (2006, 'Cedrus'),
#  (1966, 'Malus'),
#  (2006, 'Salix'),
# ...

# %%
arbres_bota_trie = sorted(arbores_uniques, key=lambda x:int(x[0]), reverse = True)
print(arbres_bota_trie[:10])
# Out:
# [(2017, 'Populus'), (2017, 'Tilia'), (2017, 'Cedrus'), (2017, 'Salix'), (2017, 'Corylus'), (2017, 'Pyrus'), (2017, 'Robinia'), (2017, 'Aesculus'), (2017, 'Platanus'), (2017, 'Alnus')]
